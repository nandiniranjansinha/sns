# %% [markdown]
# <a href="https://colab.research.google.com/github/nandiniranjansinha/sns/blob/main/SEABORN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
# either you can load files and use the uploaded datasets
# or
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# Let's just load the inbuilt datasets

tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')
titanic = sns.load_dataset('titanic')
planets = sns.load_dataset('planets')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Scatter Plot

# %%
sns.scatterplot(x = 'tip', y = 'total_bill', data = tips)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x = 'tip', y = 'total_bill', data = tips, hue = 'day', size = 'size')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x = 'tip', y = 'total_bill', data = tips, hue = 'day', size = 'size', palette = 'YlGnBu') # yellow, green, blue
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# **Built-in Seaborn Color Palettes**
# 1. **Qualitative Palettes (for categorical data)**
# - deep
# - muted
# - pastel
# - bright
# - dark
# - colorblind
#
# 2. **Sequential Palettes (for ordered data)**
# - Blues
# - BuGn
# - BuPu
# - GnBu
# - Greens
# - Greys
# - Oranges
# - OrRd
# - PuBu
# - PuBuGn
# - PuRd
# - Purples
# - RdPu
# - Reds
# - YlGn
# - YlGnBu
# - YlOrBr
# - YlOrRd
#
# 3. **Diverging Palettes (for data with a midpoint)**
# - BrBG
# - PiYG
# - PRGn
# - PuOr
# - RdBu
# - RdGy
# - RdYlBu
# - RdYlGn
# - Spectral
#
#
# **Other Seaborn Palette Functions and Options**
# 1. sns.color_palette() — lets you specify any palette by name or a list of colors.
#
# 2. sns.light_palette(color, reverse=False) — create a sequential palette from a single color.
#
# 3. sns.dark_palette(color, reverse=False) — darker sequential palette.
#
# 4. sns.diverging_palette(h_neg, h_pos, s=75, l=40, n=6, center='light') — custom diverging palette.
#
# 5. sns.cubehelix_palette() — sequential palette based on cubehelix color scheme.
#
# 6. sns.mpl_palette() — use matplotlib colormaps as palettes.
#
# 7. sns.xkcd_palette() — palette based on XKCD color names.

# %% [markdown]
# ## Histogram

# %%
# kde -> if we want a line too then set it to True

sns.histplot(tips['tip'], kde = True, bins = 15)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(tips['tip'], kde = True, bins = 30)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(tips['tip'], kde = False, bins = 15) # or simply leave kde
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# ## Distribution Plot

# %%
sns.distplot(tips['tip'], kde = True, bins = 15)
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.distplot(tips['tip'], kde = False, bins = 15)
# Out:
# <ipython-input-15-1c3dbbf17910>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['tip'], kde = False, bins = 15)
# <Axes: xlabel='tip'>

# %% [markdown]
# kde=False means no KDE curve is drawn, just the histogram bars.
#
# The warning suggests switching to sns.histplot() for this.
#
# How to fix your code:
# Replace with
#
# `sns.histplot(tips['tip'], kde=False, bins=15)`
#
# This will give you the same plot without the warning.

# %% [markdown]
# 1. distplot (Deprecated)
#
# - What it is:
#   An older function that combined both histogram and KDE plotting into one.
#
# - Key points:
#   - Can plot histogram and/or KDE on the same axes.
#   - Flexible but limited to one plot on one axes.
#   - Deprecated as of Seaborn 0.11 and removed in 0.14.
#   - Raises warnings if used now.
#
# - Example:
# `sns.distplot(data, bins=20, kde=True)`
#
# 2. histplot (Axes-level function)
#
# - What it is: A newer function designed specifically for histograms and optionally KDE.
#
# - Key points:
#   - Plots histogram on a single axes.
#   - Can overlay KDE by setting kde=True.
#   - More features and better integration with Seaborn’s new API.
#   - Replaces most uses of distplot when you want a histogram.
#
# - Example:
# `sns.histplot(data, bins=20, kde=True)`
#
# 3. displot (Figure-level function)
#
# - What it is:
# A figure-level function that creates a figure with multiple facets (subplots) if desired.
#
# - Key points:
#   - Creates a FacetGrid by default, useful for plotting distributions by subsets of data.
#   - Can plot histogram, KDE, or both.
#   - Supports faceting with col=, row=, hue= parameters.
#   - More flexible for exploratory data analysis with multiple groups.
#
# - Example:
# `sns.displot(data, bins=20, kde=True)` or with faceting:
#
#   `sns.displot(data, col="category", kde=True)`

# %%
# All three are distribution plots only

# %%
sns.displot(tips['tip'], kde = False, bins = 15)

# %%
sns.displot(tips['tip'], kde = True, bins = 15)

# %% [markdown]
# ## Bar Plot

# %%
sns.barplot(x = 'sex', y = 'tip', data = tips, palette = 'pastel')
# Out:
# <ipython-input-25-60180a44f209>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'sex', y = 'tip', data = tips, palette = 'pastel')
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# **The warning means:**
#
# - You passed a palette argument to sns.barplot() without using a hue parameter.
#
# - This usage is deprecated and will be removed in Seaborn version 0.14.0.
#
# - Seaborn expects you to use palette only when you have a hue variable to color different groups.
#
# - If you want colors for the bars without grouping by hue, Seaborn suggests a workaround:
#
#       Set hue='sex' (same as x variable), and
#
#       Set legend=False to avoid showing the legend.
#
# **Why this happens**
#
# - Palette is meant to specify colors for groups created by the hue variable.
#
# - Without hue, Seaborn is warning that using palette is not the intended way to color bars.

# %%
sns.barplot(x='sex', y='tip', data=tips, hue='sex', palette='pastel', legend=False)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.barplot(x='sex', y='tip', data=tips, hue='sex', palette='pastel')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(x = 'day', y = 'tip', data = tips, hue = 'sex', palette = 'YlGnBu')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex', palette = 'YlGnBu')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Strip Plot

# %%
sns.stripplot(x = 'day', y = 'tip', data = tips, hue = 'sex', palette = 'YlGnBu')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
# dodge used to separate the hues

sns.stripplot(x = 'day', y = 'tip', data = tips, hue = 'sex', palette = 'YlGnBu', dodge = True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## Joint Plot -> Combination of Scatter and Distribution Plots

# %%
sns.jointplot(x = 'day', y = 'tip', data = tips)

# %%
sns.jointplot(x = 'tip', y = 'total_bill', data = tips)

# %%
sns.jointplot(x = 'tip', y = 'total_bill', data = tips, kind = 'reg') # kind = reg for regression

# %%
sns.jointplot(x = 'tip', y = 'total_bill', data = tips, kind = 'kde')

# KDE = Kernel Density Estimate
# It’s a method to estimate the probability density function (PDF) of a continuous random variable — basically a smooth version of a histogram.

# %%
# shade tells conc of values
sns.jointplot(x = 'tip', y = 'total_bill', data = tips, kind = 'kde', shade = True)
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:1832: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
sns.jointplot(x = 'tip', y = 'total_bill', data = tips, kind = 'kde', shade = True, cmap = 'YlGnBu')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:1832: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
sns.jointplot(x = 'tip', y = 'total_bill', data = tips, kind = 'hex', cmap = 'YlGnBu')

# darker - more conc

# %% [markdown]
# ## Pair Plot

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.pairplot(titanic.select_dtypes(['number']), hue = 'pclass')

# %%
sns.pairplot(titanic.select_dtypes(['number']), hue = 'sibsp')

# %%
sns.pairplot(titanic.select_dtypes(['number']), hue = 'parch')

# %%
# Correlation between the individuals

titanic.select_dtypes(['number']).corr()
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
titanic.select_dtypes(['number','bool']).corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %% [markdown]
# ## Heat Map

# %%
# annot - Annotations
correlation = titanic.select_dtypes(['number','bool']).corr()

sns.heatmap(correlation, annot = True, cmap = 'YlGnBu')

# high corr - near 1 or 1
# Out:
# <Axes: >

# %%
sns.heatmap(correlation, annot = False, cmap = 'YlGnBu')
# Out:
# <Axes: >

# %%
sns.heatmap(correlation, annot = True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
sns.heatmap(correlation, annot = True, cmap = 'icefire')
# Out:
# <Axes: >

# %% [markdown]
# ## Cluster Map

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# drop the non-numeric column
# axis = 1 -> column

sns.clustermap(iris.drop('species', axis = 1))

# %%
# useful for Unsupervised Learning
# useful for smaller plots
